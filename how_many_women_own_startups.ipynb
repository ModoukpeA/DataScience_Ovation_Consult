# %% [markdown]
# #  Data Analysis With Python #

# %%
"""
In this python file, I will make a brief analysis of data contained in the entreprise excel file.
"""
# Out:
# '\nIn this python file, I will make a brief analysis of data contained in the entreprise excel file.\n'

# %%
# I will use Pandas and Matplotlib Libraries to perform this task

#Let's import them

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# Creating a variable to store the file content
mydata = pd.read_excel ("ENTREPRISES_BENIN.xlsx")

# Printing the content of the file (all the columns are displayed )
print (mydata)
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  ENTREPRISES BENINOISES SUSCEPTIBLES D'ENGAGER ...
# 1          NaN                                       DENOMINATION
# 2          NaN                                             IT-NUM
# 3          NaN                                       BLOLAB BENIN
# 4          NaN                                       IROKO FABLAB
# 5          NaN                                              YLOMI
# 6          NaN                                       KEA MEDICALS
# 7          NaN                                            OPEN SI
# 8          NaN                                  CFAO TECHNOLOGIES
# 9          NaN                                     KUTONOU AGENCY
# 10         NaN                                       ESSN ECOTECH
# 11         NaN                                              ATERI
# 12         NaN                                       BE SOLUTIONS
# ...

# %%
# Showing all the rows
mydata
# Out:
#     Unnamed: 0                                         Unnamed: 1  \
# 0          NaN  ENTREPRISES BENINOISES SUSCEPTIBLES D'ENGAGER ...
# 1          NaN                                       DENOMINATION
# 2          NaN                                             IT-NUM
# 3          NaN                                       BLOLAB BENIN
# 4          NaN                                       IROKO FABLAB
# 5          NaN                                              YLOMI
# 6          NaN                                       KEA MEDICALS
# 7          NaN                                            OPEN SI
# 8          NaN                                  CFAO TECHNOLOGIES
# 9          NaN                                     KUTONOU AGENCY
# 10         NaN                                       ESSN ECOTECH
# 11         NaN                                              ATERI
# 12         NaN                                       BE SOLUTIONS
# ...

# %%
# Displaying the 5 first rows of our file
mydata.head()
# Out:
#    Unnamed: 0                                         Unnamed: 1  \
# 0         NaN  ENTREPRISES BENINOISES SUSCEPTIBLES D'ENGAGER ...
# 1         NaN                                       DENOMINATION
# 2         NaN                                             IT-NUM
# 3         NaN                                       BLOLAB BENIN
# 4         NaN                                       IROKO FABLAB
#
#             Unnamed: 2                               Unnamed: 3 Unnamed: 4  \
# 0                  NaN                                      NaN        NaN
# 1  DOMAINE D'ACTIVITES                                SITES WEB   CONTACTS
# 2                   IT                      https://it-num.com/        NaN
# 3                   IT                      https://blolab.org/        NaN
# 4                   IT  https://www.fablabs.io/labs/Irokofablab        NaN
#
#          Unnamed: 5    Unnamed: 6
# 0               NaN           NaN
# 1           MANAGER  SEXE MANAGER
# ...

# %%
# Displaying the last 5 rows of our file
mydata.tail()
# Out:
#     Unnamed: 0           Unnamed: 1     Unnamed: 2  \
# 15         NaN               PRONUM             IT
# 16         NaN    WURAMI CONSULTING       FINANCES
# 17         NaN  CEPHAS TECHNOLOGIES             IT
# 18         NaN              THE WAY  IT, EDUCATION
# 19         NaN            EDOWABOSA             IT
#
#                              Unnamed: 3 Unnamed: 4  \
# 15  https://web.facebook.com/pronumltd/        NaN
# 16              http://www.ewurami.com/        NaN
# 17                                  NaN        NaN
# 18                                  NaN        NaN
# 19                                  NaN        NaN
#
#                              Unnamed: 5 Unnamed: 6
# 15  Eude Assogba Balle & Sylvère Akambi          M
# 16                        Ayodele Ognin          F
# 17                       Merline ATONDE          F
# 18                       Solange OLOUDE          F
# 19                Cica Clarisse OLYMPIO          F

# %%
# Getting some statistic details on the file
mydata.describe()
# Out:
#        Unnamed: 0
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Showing all the columns
mydata.columns.values
# Out:
# array(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6'], dtype=object)

# %%
# Showing all the file columns and store them in a list
mydata.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6']

# %%
# Displaying the number of lines and columns in the dataset
mydata.shape
# Out:
# (20, 7)

# %%
# Displaying data starting from the line 2
mydata[1:]
# Out:
#     Unnamed: 0           Unnamed: 1           Unnamed: 2  \
# 1          NaN         DENOMINATION  DOMAINE D'ACTIVITES
# 2          NaN               IT-NUM                   IT
# 3          NaN         BLOLAB BENIN                   IT
# 4          NaN         IROKO FABLAB                   IT
# 5          NaN                YLOMI                   IT
# 6          NaN         KEA MEDICALS                   IT
# 7          NaN              OPEN SI                   IT
# 8          NaN    CFAO TECHNOLOGIES                   IT
# 9          NaN       KUTONOU AGENCY                   IT
# 10         NaN         ESSN ECOTECH                   IT
# 11         NaN                ATERI                   IT
# 12         NaN         BE SOLUTIONS                   IT
# 13         NaN       DYNAMIQUE INFO                   IT
# 14         NaN        PLURI CONSULT                   IT
# 15         NaN               PRONUM                   IT
# ...

# %%
# Displaying the line on which columns are
mydata [1:2]
# Out:
#    Unnamed: 0    Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 1         NaN  DENOMINATION  DOMAINE D'ACTIVITES  SITES WEB   CONTACTS
#
#   Unnamed: 5    Unnamed: 6
# 1    MANAGER  SEXE MANAGER

# %%
# Counting the occurences in sex column
mydata['Unnamed: 6'].value_counts()
# Out:
# M               8
# F               6
# SEXE MANAGER    1
# Name: Unnamed: 6, dtype: int64

# %% [markdown]
# ## Représentation Graphique (Sexe Manager)

# %%
x=np.array(["Masculin", "Féminin"])
y=np.array([8,6])
sexe_colors= np.array(["red","indigo"])
plt.pie(y, colors=sexe_colors, labels=x)
plt.legend(title="Managers")
plt.show()
